# %%
# Problem 1: Write a code to take username as input and return its length.

user_name = input("Enter your name: ")
print(len(user_name))

# %%
#EWrite a code to take

first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
print(len(first_name)+len(last_name))
# Out:
# Enter your first name: Venkatesh
# Enter your last name: Ravva
# 14

# %%
first_name, last_name = input("Enter your first name and last name: ").split(",")
print(len(first_name)+len(last_name))
# Out:
# Enter your first name and last name: venkatesh,ravva
# 14

# %%
#Write a program to take two numbers and return the product.

number1 = int(input("Enter number1: "))
number2 = float(input("Enter numner2: "))
product = number1*number2
print(product)
# Out:
# Enter number1: 5
# Enter numner2: 6.7
# 33.5

# %%
num1, num2 = input("Enter two numbers: ").split(",")
print(int(num1)*float(num2))
#
# Out:
# Enter two numbers: 5,5.5
# 27.5

# %%
num1, num2 = input("Enter two numbers: ").split(",")
sum_of_squares = int(num1)**2 + int(num2)**2
print(sum_of_squares)
# Out:
# Enter two numbers: 2,4
# 20

# %%
num1, num2, num3 = input("Enter three numbers: ").split(",")
sum_of_squares = int(num1)**2 + int(num2)**2 + int(num3)**2
print(sum_of_squares)
# Out:
# Enter two numbers: 2,2,2
# 12

# %%
# problem 7: write a program to take 3 numbers as input in a single line and ret rn the sum of their squares
a, b, c = input("Enter three numbers: "). split()

a = int(a)
b = int(b)
c = int(c)
sum_of_squares = a**2 + b**2 + c**2
print("Sum of squares:", sum_of_squares)
# Out:
# Enter three numbers: 2 2 2
# Sum of squares: 12

# %%
celcius = float(input("Enter temp in celcius:"))
fahrenheit = 9/5*(celcius) +32
print(fahrenheit)
# Out:
# Enter temp in celcius:34
# 93.2

# %%
# words = input()
# lines = set()
# for i in words:
#     if i.isalpha():
#         lines.add(i)
# if len(lines)==26:
#     print("Program")
# else:
#     print("Not Program")
