# %% [markdown]
# # Exercises: Day 6

# %% [markdown]
# ## Exercises: Day 6
# Exercises: Level 1
# 1. Create an empty tuple
# 2. Create a tuple containing names of your sisters and your brothers (imaginary siblings are fine)
# 3. Join brothers and sisters tuples and assign it to siblings
# 4. How many siblings do you have?
# 5. Modify the siblings tuple and add the name of your father and mother and assign it to family_members
#
# ## Exercises: Level 2
# 1. Unpack siblings and parents from family_members
# 2. Create fruits, vegetables and animal products tuples. Join the three tuples and assign it to a variable called food_stuff_tp.
# 3. Change the about food_stuff_tp tuple to a food_stuff_lt list
# 4. Slice out the middle item or items from the food_stuff_tp tuple or food_stuff_lt list.
# 5. Slice out the first three items and the last three items from food stuff It list
# 6. Delete the food_stuff_tp tuple completely
# 7. Check if an item exists in tuple:
# Check if 'Estonia' is a nordic country
# Check if 'Iceland' is a nordic country
# nordic_countries = ('Denmark', 'Finland', 'Iceland', 'Norway', 'Sweden')

# %%
# Exercises: Level 1

# 1. Create an empty tuple

# empty_tuple = ()

# # using tutple constructor

# empty_tuple = tuple()

# 2. Create a tuple containing names of your fav cartoons & Movies (imaginary siblings are fine)

# # cartoons = ('Doremon', 'Ben 10', 'Horried Henry', 'Roll No 21')
# movies = ('kalki 2898AD', 'Lucky bhaskar', 'Harry Potterl', 'inception')


# # 3. Join cartoons and movies tuples and assign it to siblings

# fav = cartoons + movies
# print(fav)


# 4. How many cartoons  are there?

# print(len(cartoons))


# 5. Modify the cartoons tuple and add the name of your country and state and assign it to address

# cartoons = ('Doremon', 'Ben 10', 'Horried Henry', 'Roll No 21')
# address = cartoons + ('India', 'AP')
# print(address)


# Exercises: Level 2

# 1. Unpack cartoons and moviess from family_members

cartoons = fav[:3]
movies = fav[3:]

print(cartoons)
print(movies)


# 2. Create fruits, vegetables and animal products tuples. Join the three tuples and assign it to a variable called food_stuff_tp.



# 3. Change the about food_stuff_tp tuple to a food_stuff_lt list
# 4. Slice out the middle item or items from the food_stuff_tp tuple or food_stuff_lt list.
# 5. Slice out the first three items and the last three items from food stuff It list
# 6. Delete the food_stuff_tp tuple completely
# 7. Check if an item exists in tuple:
# Check if 'Estonia' is a nordic country
# Check if 'Iceland' is a nordic country
# nordic_countries = ('Denmark', 'Finland', 'Iceland', 'Norway', 'Sweden')
# Out:
# ('Doremon', 'Ben 10', 'Horried Henry')
# ('Roll No 21', 'kalki 2898AD', 'Lucky bhaskar', 'Harry Potterl', 'inception')
